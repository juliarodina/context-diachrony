# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cosine
from scipy.stats import spearmanr

# %% [markdown]
# ## Pre-Soviet vs. Soviet

# %%
# load dataset filtered by compare mean <3 or delta_later >0.2
dataset = pd.read_csv('dataset_0_DUREL_filtered.tsv', sep='\t')
dataset.head()
# Out:
#           word  COMPARE  EARLIER  LATER  delta_later
# 0      влажный     2.82     3.03   2.59        -0.44
# 1         дума     2.25     2.38   2.30        -0.08
# 2   заведующий     3.31     3.02   3.38         0.36
# 3  заключенный     1.71     2.49   3.40         0.91
# 4     защитник     2.66     2.90   2.61        -0.29

# %%
ranked_delta = dataset.reindex(dataset.delta_later.abs().sort_values(ascending=False).index)
ranked_delta = ranked_delta.reset_index(drop=True)
ranked_delta
# Out:
#            word  COMPARE  EARLIER  LATER  delta_later
# 0        тройка     2.50     3.33   1.43        -1.90
# 1   заключенный     1.71     2.49   3.40         0.91
# 2        свалка     1.90     3.09   2.34        -0.75
# 3    насаждение     2.48     2.11   2.78         0.67
# 4        палата     1.46     2.16   1.53        -0.63
# 5         отдел     2.55     2.13   2.74         0.61
# 6        червяк     1.92     2.48   1.90        -0.58
# 7      трибунал     2.98     2.80   3.37         0.57
# 8        привет     3.24     3.03   3.55         0.52
# 9         особа     2.95     2.79   3.30         0.51
# 10        собор     2.95     2.44   2.93         0.49
# 11        уклон     2.49     1.93   2.41         0.48
# 12        пакет     2.79     2.98   2.53        -0.45
# 13       машина     2.12     2.30   2.74         0.44
# 14       секция     2.76     2.66   2.22        -0.44
# 15      влажный     2.82     3.03   2.59        -0.44
# 16      пружина     2.18     2.28   2.69         0.41
# 17       управа     3.18     3.32   2.94        -0.38
# 18   заведующий     3.31     3.02   3.38         0.36
# 19         мазь     2.87     3.44   3.13        -0.31
# 20     защитник     2.66     2.90   2.61        -0.29
# 21      элемент     1.91     2.15   1.86        -0.29
# 22     классный     2.41     3.02   2.76        -0.26
# 23      знатный     2.82     3.02   2.78        -0.24
# 24        стиль     2.41     2.83   2.60        -0.23
# 25       пионер     1.86     2.77   2.64        -0.13
# 26    передовой     2.56     2.59   2.46        -0.13
# 27      участок     1.90     2.00   2.12         0.12
# 28   управление     1.66     2.07   2.18         0.11
# 29   серединный     2.33     2.21   2.11        -0.10
# 30    отделение     2.09     2.09   2.18         0.09
# 31         дума     2.25     2.38   2.30        -0.08
# 32       трубка     2.04     2.08   2.12         0.04
# 33      молодец     2.22     2.61   2.62         0.01

# %%
ranked_compare = dataset.reindex(dataset.COMPARE.sort_values(ascending=True).index)
ranked_compare = ranked_compare.reset_index(drop=True)
ranked_compare
# Out:
#            word  COMPARE  EARLIER  LATER  delta_later
# 0        палата     1.46     2.16   1.53        -0.63
# 1    управление     1.66     2.07   2.18         0.11
# 2   заключенный     1.71     2.49   3.40         0.91
# 3        пионер     1.86     2.77   2.64        -0.13
# 4        свалка     1.90     3.09   2.34        -0.75
# 5       участок     1.90     2.00   2.12         0.12
# 6       элемент     1.91     2.15   1.86        -0.29
# 7        червяк     1.92     2.48   1.90        -0.58
# 8        трубка     2.04     2.08   2.12         0.04
# 9     отделение     2.09     2.09   2.18         0.09
# 10       машина     2.12     2.30   2.74         0.44
# 11      пружина     2.18     2.28   2.69         0.41
# 12      молодец     2.22     2.61   2.62         0.01
# 13         дума     2.25     2.38   2.30        -0.08
# 14   серединный     2.33     2.21   2.11        -0.10
# 15        стиль     2.41     2.83   2.60        -0.23
# 16     классный     2.41     3.02   2.76        -0.26
# 17   насаждение     2.48     2.11   2.78         0.67
# 18        уклон     2.49     1.93   2.41         0.48
# 19       тройка     2.50     3.33   1.43        -1.90
# 20        отдел     2.55     2.13   2.74         0.61
# 21    передовой     2.56     2.59   2.46        -0.13
# 22     защитник     2.66     2.90   2.61        -0.29
# 23       секция     2.76     2.66   2.22        -0.44
# 24        пакет     2.79     2.98   2.53        -0.45
# 25      знатный     2.82     3.02   2.78        -0.24
# 26      влажный     2.82     3.03   2.59        -0.44
# 27         мазь     2.87     3.44   3.13        -0.31
# 28        собор     2.95     2.44   2.93         0.49
# 29        особа     2.95     2.79   3.30         0.51
# 30     трибунал     2.98     2.80   3.37         0.57
# 31       управа     3.18     3.32   2.94        -0.38
# 32       привет     3.24     3.03   3.55         0.52
# 33   заведующий     3.31     3.02   3.38         0.36

# %%
target_words = dataset.word.tolist()

# %%
# token embeddings extracted using https://github.com/ltgoslo/simple_elmo

array0 = np.load('presoviet_incr_embs_0.npz')
print(len(array0))

array1 = np.load('soviet_incr_embs_0.npz')
print(len(array1))
# Out:
# 71
# 71

# %%
print(array0['собор'].shape)
array0['собор']
# Out:
# (5384, 1024)
# array([[-0.72170472,  0.09754667,  0.73101729, ..., -0.84733498,
#         -0.20107049,  0.36461118],
#        [-0.47427469,  0.004144  ,  0.08054993, ..., -0.65336466,
#         -0.59087026, -0.26150763],
#        [-1.70223987, -0.26661727,  0.1770528 , ..., -0.13750337,
#         -0.12923655,  0.34274617],
#        ...,
#        [-0.58482593, -0.21871354, -0.39251336, ..., -0.1588814 ,
#         -0.10788606, -0.39430529],
#        [-0.33000177,  0.23090473,  0.17835674, ..., -0.50444502,
#         -0.12523156,  0.37941808],
#        [-0.81413406, -0.49671683,  0.09676844, ..., -1.15526485,
#          0.10718139,  0.4539662 ]])

# %%
np.average(array0['собор'], axis=0)
# Out:
# array([-0.80992817, -0.14719359,  0.01371795, ..., -0.46227408,
#        -0.34614951,  0.10017612])

# %%
cosines = []
for word in target_words:
    vector1 = np.average(array0[word], axis=0)
    vector2 = np.average(array1[word], axis=0)
    cosdist = cosine(vector1, vector2)
    cosines.append((word, cosdist))

# %%
cosines[:3]
# Out:
# [('влажный', 0.17390895976294163),
#  ('дума', 0.22563745040880978),
#  ('заведующий', 0.19392648322273387)]

# %%
sorted_cosines = sorted(cosines, key=lambda tup: tup[1], reverse=True)
sorted_cosines = [tup[0] for tup in sorted_cosines]
sorted_cosines
# Out:
# ['заключенный',
#  'отдел',
#  'пионер',
#  'отделение',
#  'машина',
#  'пакет',
#  'дума',
#  'элемент',
#  'участок',
#  'привет',
#  'палата',
#  'пружина',
#  'трубка',
#  'заведующий',
#  'уклон',
#  'управа',
#  'управление',
#  'стиль',
#  'секция',
#  'защитник',
#  'влажный',
#  'червяк',
#  'собор',
#  'тройка',
#  'трибунал',
#  'знатный',
#  'насаждение',
#  'молодец',
#  'свалка',
#  'передовой',
#  'серединный',
#  'особа',
#  'мазь',
#  'классный']

# %%
ranks_cos = []
ranks_delta = []
ranks_compare = []
for word in target_words:
    ranks_cos.append(sorted_cosines.index(word))
    ranks_delta.append(ranked_delta.word.tolist().index(word))
    ranks_compare.append(ranked_compare.word.tolist().index(word))

# %%
coef, p = spearmanr(ranks_cos, ranks_delta)
print('Spearmans correlation coefficient: %.3f' % coef)
print('p=%.3f' % p)
# Out:
# Spearmans correlation coefficient: 0.001
# p=0.995

# %%
coef, p = spearmanr(ranks_cos, ranks_compare)
print('Spearmans correlation coefficient: %.3f' % coef)
print('p=%.3f' % p)
# Out:
# Spearmans correlation coefficient: 0.346
# p=0.045

# %%
d = [r1-r2 for r1,r2 in zip(ranks_cos, ranks_delta)]
d_2 = [diff**2 for diff in d]
summ = sum(d_2)
print(1 - ((6*summ)/((len(d)**3)-len(d))))
# Out:
# 0.0010695187165775666

# %% [markdown]
# ## Soviet vs. Post-Soviet

# %%
dataset = pd.read_csv('dataset_1_DUREL_filtered.tsv', sep='\t')
dataset.head()
# Out:
#       word  COMPARE  EARLIER  LATER  delta_later
# 0  блочный     2.15     2.57   2.63         0.06
# 1   боевик     2.25     3.28   2.82        -0.46
# 2  ботаник     2.52     3.20   2.16        -1.04
# 3    взлом     3.26     3.40   3.03        -0.37
# 4  выплеск     3.16     2.76   3.68         0.92

# %%
ranked_delta = dataset.reindex(dataset.delta_later.abs().sort_values(ascending=False).index)
ranked_delta = ranked_delta.reset_index(drop=True)
ranked_delta
# Out:
#             word  COMPARE  EARLIER  LATER  delta_later
# 0     провальный     1.96     1.87   3.65         1.78
# 1      инкубатор     2.19     3.54   2.49        -1.05
# 2        ботаник     2.52     3.20   2.16        -1.04
# 3       рыночный     2.36     2.33   3.37         1.04
# 4        выплеск     3.16     2.76   3.68         0.92
# 5      рождество     3.15     3.60   2.69        -0.91
# 6       удвоение     2.98     2.87   3.70         0.83
# 7         орбита     2.53     2.26   3.07         0.81
# 8       дивизион     3.58     3.79   3.01        -0.78
# 9          карта     1.85     2.28   1.58        -0.70
# 10   перестройка     2.14     2.43   3.10         0.67
# 11        глянец     2.12     2.86   2.21        -0.65
# 12        флакон     3.48     3.72   3.11        -0.61
# 13   погрешность     3.00     2.84   3.44         0.60
# 14         пакет     1.65     2.78   2.23        -0.55
# 15         рынок     1.82     2.59   3.10         0.51
# 16      подстава     1.00     3.30   2.80        -0.50
# 17   высоколобый     2.19     2.14   2.62         0.48
# 18        стачка     2.84     3.45   2.97        -0.48
# 19     приставка     2.13     1.97   2.45         0.48
# 20     раскрутка     2.13     2.83   3.30         0.47
# 21        боевик     2.25     3.28   2.82        -0.46
# 22    однодневка     2.56     2.76   3.22         0.46
# 23   гермафродит     3.05     3.45   3.00        -0.45
# 24         стиль     2.74     2.83   2.43        -0.40
# 25     ломберный     3.72     3.94   3.55        -0.39
# 26    приношение     2.91     3.22   2.84        -0.38
# 27         взлом     3.26     3.40   3.03        -0.37
# 28          мыло     3.21     3.43   3.07        -0.36
# 29      загрузка     2.09     2.54   2.19        -0.35
# 30        корпус     1.77     2.26   1.95        -0.31
# 31         знамя     3.11     2.97   2.66        -0.31
# 32       завязка     1.86     2.07   1.77        -0.30
# 33          игра     2.28     2.39   2.11        -0.28
# 34     донорство     2.72     3.62   3.34        -0.28
# 35  четырехлетка     1.07     3.07   2.80        -0.27
# 36      классный     1.43     2.44   2.17        -0.27
# 37        модель     2.49     2.21   1.97        -0.24
# 38     свинцовый     1.99     2.17   1.93        -0.24
# 39       драйвер     1.29     3.00   2.80        -0.20
# 40   исполнитель     2.60     2.74   2.54        -0.20
# 41        двушка     1.38     2.65   2.56        -0.09
# 42       блочный     2.15     2.57   2.63         0.06

# %%
ranked_compare = dataset.reindex(dataset.COMPARE.sort_values(ascending=True).index)
ranked_compare = ranked_compare.reset_index(drop=True)
ranked_compare
# Out:
#             word  COMPARE  EARLIER  LATER  delta_later
# 0       подстава     1.00     3.30   2.80        -0.50
# 1   четырехлетка     1.07     3.07   2.80        -0.27
# 2        драйвер     1.29     3.00   2.80        -0.20
# 3         двушка     1.38     2.65   2.56        -0.09
# 4       классный     1.43     2.44   2.17        -0.27
# 5          пакет     1.65     2.78   2.23        -0.55
# 6         корпус     1.77     2.26   1.95        -0.31
# 7          рынок     1.82     2.59   3.10         0.51
# 8          карта     1.85     2.28   1.58        -0.70
# 9        завязка     1.86     2.07   1.77        -0.30
# 10    провальный     1.96     1.87   3.65         1.78
# 11     свинцовый     1.99     2.17   1.93        -0.24
# 12      загрузка     2.09     2.54   2.19        -0.35
# 13        глянец     2.12     2.86   2.21        -0.65
# 14     приставка     2.13     1.97   2.45         0.48
# 15     раскрутка     2.13     2.83   3.30         0.47
# 16   перестройка     2.14     2.43   3.10         0.67
# 17       блочный     2.15     2.57   2.63         0.06
# 18     инкубатор     2.19     3.54   2.49        -1.05
# 19   высоколобый     2.19     2.14   2.62         0.48
# 20        боевик     2.25     3.28   2.82        -0.46
# 21          игра     2.28     2.39   2.11        -0.28
# 22      рыночный     2.36     2.33   3.37         1.04
# 23        модель     2.49     2.21   1.97        -0.24
# 24       ботаник     2.52     3.20   2.16        -1.04
# 25        орбита     2.53     2.26   3.07         0.81
# 26    однодневка     2.56     2.76   3.22         0.46
# 27   исполнитель     2.60     2.74   2.54        -0.20
# 28     донорство     2.72     3.62   3.34        -0.28
# 29         стиль     2.74     2.83   2.43        -0.40
# 30        стачка     2.84     3.45   2.97        -0.48
# 31    приношение     2.91     3.22   2.84        -0.38
# 32      удвоение     2.98     2.87   3.70         0.83
# 33   погрешность     3.00     2.84   3.44         0.60
# 34   гермафродит     3.05     3.45   3.00        -0.45
# 35         знамя     3.11     2.97   2.66        -0.31
# 36     рождество     3.15     3.60   2.69        -0.91
# 37       выплеск     3.16     2.76   3.68         0.92
# 38          мыло     3.21     3.43   3.07        -0.36
# 39         взлом     3.26     3.40   3.03        -0.37
# 40        флакон     3.48     3.72   3.11        -0.61
# 41      дивизион     3.58     3.79   3.01        -0.78
# 42     ломберный     3.72     3.94   3.55        -0.39

# %%
target_words = dataset.word.tolist()

# %%
# token embeddings extracted using https://github.com/ltgoslo/simple_elmo

array0 = np.load('soviet_incr_embs_1.npz')
print(len(array0))

array1 = np.load('postsoviet_incr_embs_1.npz')
print(len(array1))
# Out:
# 69
# 69

# %%
cosines = []
for word in target_words:
    vector1 = np.average(array0[word], axis=0)
    vector2 = np.average(array1[word], axis=0)
    cosdist = cosine(vector1, vector2)
    cosines.append((word, cosdist))

# %%
sorted_cosines = sorted(cosines, key=lambda tup: tup[1], reverse=True)
sorted_cosines = [tup[0] for tup in sorted_cosines]
sorted_cosines
# Out:
# ['четырехлетка',
#  'рынок',
#  'исполнитель',
#  'орбита',
#  'флакон',
#  'приставка',
#  'драйвер',
#  'раскрутка',
#  'двушка',
#  'подстава',
#  'ботаник',
#  'блочный',
#  'рождество',
#  'классный',
#  'донорство',
#  'рыночный',
#  'гермафродит',
#  'дивизион',
#  'стачка',
#  'глянец',
#  'знамя',
#  'модель',
#  'перестройка',
#  'провальный',
#  'пакет',
#  'стиль',
#  'корпус',
#  'удвоение',
#  'боевик',
#  'завязка',
#  'однодневка',
#  'инкубатор',
#  'приношение',
#  'мыло',
#  'погрешность',
#  'ломберный',
#  'взлом',
#  'игра',
#  'свинцовый',
#  'выплеск',
#  'загрузка',
#  'карта',
#  'высоколобый']

# %%
ranks_cos = []
ranks_delta = []
ranks_compare = []
for word in target_words:
    ranks_cos.append(sorted_cosines.index(word))
    ranks_delta.append(ranked_delta.word.tolist().index(word))
    ranks_compare.append(ranked_compare.word.tolist().index(word))

# %%
coef, p = spearmanr(ranks_cos, ranks_delta)
print('Spearmans correlation coefficient: %.3f' % coef)
print('p=%.3f' % p)
# Out:
# Spearmans correlation coefficient: -0.072
# p=0.645

# %%
coef, p = spearmanr(ranks_cos, ranks_compare)
print('Spearmans correlation coefficient: %.3f' % coef)
print('p=%.3f' % p)
# Out:
# Spearmans correlation coefficient: 0.223
# p=0.150
